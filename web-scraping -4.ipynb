# %% [markdown]
# Scrape the details of most viewed videos on YouTube from Wikipedia.
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
# You need to find following details:
#
# A) Rank
#
# B) Name
#
# C) Artist
#
# D) Upload date
#
# E) Views

# %%
import selenium 
import pandas as pd
from selenium import webdriver
import requests
from bs4 import BeautifulSoup
import os
import urllib
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementClickInterceptedException
from selenium.webdriver.support.ui import WebDriverWait       
from selenium.webdriver.common.by import By       
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.alert import Alert
import time
from selenium.webdriver.common.keys import Keys
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Url= https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos

# %%
drivers= webdriver.Chrome(r"C:\Users\Sanjana\Downloads\chromedriver_win32\chromedriver.exe")
drivers.get("https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos")

# %%
#getting the page source 
time.sleep(2)
html = drivers.page_source

# %%
#Reading the tabels in HTML
df = pd.read_html(html)

# %%
df_YT= df[5]

# %%
df_YT
# Out:
#                            Video name  \
# 0               "Baby Shark Dance"[3]
# 1                      "Despacito"[5]
# 2                 "See You Again"[14]
# 3                "Gangnam Style"⁂[24]
# 4                         "Baby"*[58]
# 5                   "Bad Romance"[62]
# 6        "Charlie Bit My Finger"‡[66]
# 7            "Evolution of Dance"[68]
# 8               "Girlfriend"‡[70][71]
# 9            "Evolution of Dance"[68]
# 10     "Music Is My Hot Hot Sex"‡[74]
# 11          "Evolution of Dance"*[68]
# 12   "Pokemon Theme Music Video"‡[79]
# 13     "Myspace – The Movie"‡[83][84]
# 14           "Phony Photo Booth"‡[86]
# 15   "The Chronic of Narnia Rap"‡[88]
# 16  "Ronaldinho: Touch of Gold"‡*[90]
# 17                  "I/O Brush"‡*[93]
# 18                "Me at the zoo"[95]
# 19              As of January 6, 2022
#
#                                        Uploader                 Views*  \
# 0   Pinkfong Baby Shark - Kids' Songs & Stories             7037500000
# ...

# %%
df_YT.drop(["Notes"],axis='columns', inplace=True)

# %%
df_YT.drop(19,axis=0, inplace=True)

# %%
df_YT.drop(["Ref"],axis='columns', inplace=True)

# %%
df_YT
# Out:
#                            Video name  \
# 0               "Baby Shark Dance"[3]
# 1                      "Despacito"[5]
# 2                 "See You Again"[14]
# 3                "Gangnam Style"⁂[24]
# 4                         "Baby"*[58]
# 5                   "Bad Romance"[62]
# 6        "Charlie Bit My Finger"‡[66]
# 7            "Evolution of Dance"[68]
# 8               "Girlfriend"‡[70][71]
# 9            "Evolution of Dance"[68]
# 10     "Music Is My Hot Hot Sex"‡[74]
# 11          "Evolution of Dance"*[68]
# 12   "Pokemon Theme Music Video"‡[79]
# 13     "Myspace – The Movie"‡[83][84]
# 14           "Phony Photo Booth"‡[86]
# 15   "The Chronic of Narnia Rap"‡[88]
# 16  "Ronaldinho: Touch of Gold"‡*[90]
# 17                  "I/O Brush"‡*[93]
# 18                "Me at the zoo"[95]
#
#                                        Uploader      Views*  \
# 0   Pinkfong Baby Shark - Kids' Songs & Stories  7037500000
# 1                                    Luis Fonsi  2993700000
# ...

# %% [markdown]
# 2.Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1
# st ODI)
# B) Series
# C) Place
# D) Date
# E) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
driver= webdriver.Chrome(r"C:\Users\Sanjana\Downloads\chromedriver_win32\chromedriver.exe")

# %%
#getting the specified url
url = "https://www.bcci.tv/"
driver.get(url)
time.sleep(3)

# %%
page2 = requests.get(url)
soup2 = BeautifulSoup(page2.content)

# %%
Options_btn = driver.find_element_by_xpath('//*[@id="nav-main"]/div/button').click()

# %%
Infix_btn = driver.find_element_by_xpath('//*[@id="navigation"]/ul[1]/li[2]/a').click()
time.sleep(5)

# %%
Creating empty list
Match_title = []
Series = []
Place = []
Date = []
Time = []

# %%
#Scraping data of Series
for i in driver.find_elements_by_xpath('//*[@class="fix-text"]'):
    Series.append(i.text.replace('\n',''))

# %%
Series=Series[1:16:2]

# %%
Series
# Out:
# ['INDIA TOUR OF SOUTH AFRICA TEST SERIES 2021-22',
#  'INDIA TOUR OF SOUTH AFRICA ODI SERIES 2021/22',
#  'INDIA TOUR OF SOUTH AFRICA ODI SERIES 2021/22',
#  'INDIA TOUR OF SOUTH AFRICA ODI SERIES 2021/22',
#  'WEST INDIES TOUR OF INDIA ODI SERIES 2022',
#  'WEST INDIES TOUR OF INDIA ODI SERIES 2022',
#  'WEST INDIES TOUR OF INDIA ODI SERIES 2022',
#  'WEST INDIES TOUR OF INDIA T20 SERIES 2022']

# %%
 #Scraping data of Place
for i in driver.find_elements_by_xpath('//*[@class="fix-place ng-binding ng-scope"]'):
    Place.append(i.text[11:40])

# %%
Place
# Out:
# ['Newlands, Cape Town',
#  'oland Park, Paarl',
#  'oland Park, Paarl',
#  'ewlands, Cape Town',
#  'ARENDRA MODI STADIUM, Ahmedab',
#  'awai Mansingh Stadium, Jaipur',
#  'den Gardens, Kolkata',
#  'Barabati Stadium, Cuttack']

# %%
#Scraping data of Match_title
for i in driver.find_elements_by_xpath('//*[@class="fix-place ng-binding ng-scope"]'):
    Match_title.append(i.text[0:8])

# %%
Match_title
# Out:
# ['3rd Test',
#  '1st ODI ',
#  '2nd ODI ',
#  '3rd ODI ',
#  '1st ODI ',
#  '2nd ODI ',
#  '3rd ODI ',
#  '1st T20I']

# %%
#Scraping data of Date
for i in driver.find_elements_by_xpath('//*[@class="match-card-left match-schedule"]'):
    Date.append(i.text)

# %%
Date
# Out:
# ['11 JAN 2022',
#  '19 JAN 2022',
#  '21 JAN 2022',
#  '23 JAN 2022',
#  '6 FEB 2022',
#  '9 FEB 2022',
#  '12 FEB 2022',
#  '15 FEB 2022']

# %%
#Scraping data of Time
for i in driver.find_elements_by_xpath('//*[@class="text-right ng-binding"]'):
    Time.append(i.text)

# %%
Time
# Out:
# ['2:00 PM IST',
#  '2:00 PM IST',
#  '2:00 PM IST',
#  '2:00 PM IST',
#  '9:30 AM IST',
#  '9:30 AM IST',
#  '9:30 AM IST',
#  '7:30 PM IST']

# %%
data= list(zip(Match_title,Series,Place,Date,Time))

# %%
df_fixture= pd.DataFrame(data,columns=["Match_title","Series","Place","Date","Time"])

# %%
df_fixture
# Out:
#   Match_title                                          Series  \
# 0    3rd Test  INDIA TOUR OF SOUTH AFRICA TEST SERIES 2021-22
# 1    1st ODI    INDIA TOUR OF SOUTH AFRICA ODI SERIES 2021/22
# 2    2nd ODI    INDIA TOUR OF SOUTH AFRICA ODI SERIES 2021/22
# 3    3rd ODI    INDIA TOUR OF SOUTH AFRICA ODI SERIES 2021/22
# 4    1st ODI        WEST INDIES TOUR OF INDIA ODI SERIES 2022
# 5    2nd ODI        WEST INDIES TOUR OF INDIA ODI SERIES 2022
# 6    3rd ODI        WEST INDIES TOUR OF INDIA ODI SERIES 2022
# 7    1st T20I       WEST INDIES TOUR OF INDIA T20 SERIES 2022
#
#                            Place         Date         Time
# 0            Newlands, Cape Town  11 JAN 2022  2:00 PM IST
# 1              oland Park, Paarl  19 JAN 2022  2:00 PM IST
# 2              oland Park, Paarl  21 JAN 2022  2:00 PM IST
# 3             ewlands, Cape Town  23 JAN 2022  2:00 PM IST
# 4  ARENDRA MODI STADIUM, Ahmedab   6 FEB 2022  9:30 AM IST
# ...

# %% [markdown]
# 3.Scrape the details of selenium exception from guru99.com.
# Url = https://www.guru99.com/
# You need to find following details:
# A) Name
# B) Description
# Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
driver= webdriver.Chrome(r"C:\Users\Sanjana\Downloads\chromedriver_win32\chromedriver.exe")

# %%
#getting the specified url
url = "https://www.guru99.com/"
driver.get(url)
time.sleep(3)

# %%
driver.find_element_by_xpath('//a[@title="Selenium"]').click()

# %%
driver.find_element_by_xpath('//a[@title="Selenium Exception Handling (Common Exceptions List)"]').click()

# %%
Name=[]
Description=[]

# %%
dt = driver.find_elements_by_xpath('//table[@class="table table-striped"]/tbody/tr/td[1]')
for d in dt:
    Name.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//table[@class="table table-striped"]/tbody/tr/td[2]')
for d in dt:
    Description.append(d.text)

# %%
import pandas as pd
table=pd.DataFrame({})

table['Name']=Name[1:50]
table['Description']=Description[1:50]

table
# Out:
#                                    Name  \
# 0         ElementNotSelectableException
# 1                NoSuchElementException
# 2                  NoSuchFrameException
# 3               NoAlertPresentException
# 4                 NoSuchWindowException
# 5        StaleElementReferenceException
# 6              SessionNotFoundException
# 7                      TimeoutException
# 8                    WebDriverException
# 9             ConnectionClosedException
# 10     ElementClickInterceptedException
# 11      ElementNotInteractableException
# 12             ErrorInResponseException
# 13  ErrorHandler.UnknownServerException
# 14         ImeActivationFailedException
# 15             ImeNotAvailableException
# 16         InsecureCertificateException
# 17             InvalidArgumentException
# 18         InvalidCookieDomainException
# 19          InvalidCoordinatesException
# 20          InvalidElementStateExceptio
# 21            InvalidSessionIdException
# ...

# %% [markdown]
# 4.Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
# You have to find following details:
# A) Rank
# B) State
# C) GSDP
# D) GSDP
# E) Share
# F) GDP($ billion)
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
driver= webdriver.Chrome(r"C:\Users\Sanjana\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get('http://statisticstimes.com/')

# %%
WebDriverWait(driver, 5).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="top"]/div[2]/div[2]/button/i'))).click()

# %%
WebDriverWait(driver, 5).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="top"]/div[2]/div[2]/div/a[3]'))).click()

# %%
Rank=[]
State=[]
GSDP19_20=[]
GSDP18_19=[]
Share2018=[]
GDP_billion=[]

# %%
dt = driver.find_elements_by_xpath('//ul[@style="list-style-type:none;margin-left:20px;"]/li[1]')
dt[0].click()

# %%
dt = driver.find_elements_by_xpath('//table[@id="table_id"]/tbody/tr/td[1]')
for d in dt:
    Rank.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//table[@id="table_id"]/tbody/tr/td[2]')
for d in dt:
    State.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//table[@id="table_id"]/tbody/tr/td[3]')
for d in dt:
    GSDP19_20.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//table[@id="table_id"]/tbody/tr/td[4]')
for d in dt:
    GSDP18_19.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//table[@id="table_id"]/tbody/tr/td[5]')
for d in dt:
    Share2018.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//table[@id="table_id"]/tbody/tr/td[6]')
for d in dt:
    GDP_billion.append(d.text)

# %%
import pandas as pd
table=pd.DataFrame({})

table['Rank']=Rank
table['State']=State
table['GSDP(19-20)']=GSDP19_20
table['GSDP(18-19)']=GSDP18_19
table['Share(18-19)']=Share2018
table['GDP($billion)']=GDP_billion

table
# Out:
#    Rank                      State GSDP(19-20) GSDP(18-19) Share(18-19)  \
# 0     1                Maharashtra           -   2,632,792       13.94%
# 1     2                 Tamil Nadu   1,845,853   1,630,208        8.63%
# 2     3              Uttar Pradesh   1,687,818   1,584,764        8.39%
# 3     4                    Gujarat           -   1,502,899        7.96%
# 4     5                  Karnataka   1,631,977   1,493,127        7.91%
# 5     6                West Bengal   1,253,832   1,089,898        5.77%
# 6     7                  Rajasthan   1,020,989     942,586        4.99%
# 7     8             Andhra Pradesh     972,782     862,957        4.57%
# 8     9                  Telangana     969,604     861,031        4.56%
# 9    10             Madhya Pradesh     906,672     809,592        4.29%
# 10   11                     Kerala           -     781,653        4.14%
# 11   12                      Delhi     856,112     774,870        4.10%
# ...

# %% [markdown]
# 5.Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used

# %%
driver= webdriver.Chrome(r"C:\Users\Sanjana\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get('https://github.com/')

# %%
#Clicking on Explore
WebDriverWait(driver, 5).until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/header/div/div[1]/div[2]/button'))).click()

# %%
#Clicking on Trending
WebDriverWait(driver, 5).until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/summary'))).click()

# %%
# /html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul/li[5]/a
WebDriverWait(driver, 5).until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul/li[5]/a'))).click()

# %%
Repository_title=[]
Repository_description=[]
Contributors_count=[] 
Language_used=[]

# %%
dt = driver.find_elements_by_xpath('//span[@class="text-normal"]')
for d in dt:
    if d.text is None :
        Repository_title.append('-')
    else:
        Repository_title.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//*[@class="col-9 color-fg-muted my-1 pr-4"]')
for d in dt:
    if d.text is None :
        Repository_description.append('-')
    else:
        Repository_description.append(d.text)

# %%
len(Language_used)
# Out:
# 21

# %%
dt = driver.find_elements_by_xpath('//*[@class="f6 color-fg-muted mt-2"]/a[2]')
for d in dt:
    if d.text is None :
        Contributors_count.append('-')
    else:
        Contributors_count.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//span[@itemprop="programmingLanguage"]')
for d in dt:    
    if d.text is None :
            Language_used.append('-') 
    else:
            Language_used.append(d.text)

# %%
import pandas as pd
table=pd.DataFrame({})

table['Repository Title']=Repository_title[:21]
table['Repository Description']=Repository_description[:21]
table['Contributors Count']=Contributors_count[:21]
table['Language Used']=Language_used[:21]

table
# Out:
#           Repository Title                             Repository Description  \
# 0                  Marak /            What really happened with Aaron Swartz?
# 1              ReactiveX /            What really happened with Aaron Swartz?
# 2              LingDong- /                      Reactive Programming in Swift
# 3             tensorflow /  Procedurally generated Chinese landscape paint...
# 4           freeCodeCamp /  An Open Source Machine Learning Framework for ...
# 5              Igglybuff /  freeCodeCamp.org's open-source codebase and cu...
# 6           LaravelDaily /   A curated list of awesome warez and piracy links
# 7               Asabeneh /                           Awesome tips for Laravel
# 8           withshepherd /  30 days of JavaScript programming challenge is...
# 9            MichaelCade /  This repository is my documenting repository f...
# 10              ascoders /                              前端精读周刊。帮你理解最前沿、实用的技术。
# ...

# %% [markdown]
# 6. Scrape the details of top 100 songs on billiboard.com.
# Url = https:/www.billboard.com/
# You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
driver= webdriver.Chrome(r"C:\Users\Sanjana\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get('http://www.billboard.com/')

# %%
WebDriverWait(driver, 5).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="main-wrapper"]/header/div[1]/div/div/div[1]/button'))).click()

# %%
WebDriverWait(driver, 5).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="mega-menu-item-charts"]/a'))).click()

# %%
WebDriverWait(driver, 5).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="main-wrapper"]/main/div[2]/div[1]/div[2]/div/div[1]/div[3]/a'))).click()

# %%
Song_names=[]
Artist_name=[]
Last_week_rank=[]
Peak_rank=[]
Weeks_on_board=[]

# %%
dt = driver.find_elements_by_xpath('//*[@id="title-of-a-story"]')
for d in dt:
    if d.text is None :
        Song_name.append('-')
    else:
        Song_name.append(d.text.replace('\n',''))

# %%
Song_names=Song_name[4:204:2]

# %%
len(Song_names)
# Out:
# 100

# %%
dt = driver.find_elements_by_xpath('//*[@class="lrv-a-unstyle-list lrv-u-flex lrv-u-height-100p lrv-u-flex-direction-column@mobile-max"]')
for d in dt:
#     if d.text is None :
#         Artist_name.append('-')
#     else:
    Artist_name.append(d.text.replace('\n',''))

# %%
Artist_name
# Out:
# ['30\nAdele\n1\n1\n6',
#  '30Adele116',
#  'Adele',
#  'ChristmasMichael Buble',
#  'ChristmasMichael Buble',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '21100',
#  'ChristmasMichael Buble21100',
#  'ChristmasMichael Buble21100',
#  'ChristmasMichael Buble21100',
#  '30Adele116',
#  'ChristmasMichael Buble21100',
#  "Red (Taylor's Version)Taylor Swift317",
#  'SourOlivia Rodrigo5132',
#  'Dangerous: The Double AlbumMorgan Wallen12151',
#  'The Christmas SongNat King Cole8665',
#  'EncantoSoundtrack11075',
#  'A Charlie Brown Christmas (Soundtrack)Vince Guaraldi Trio6699',
#  'Merry ChristmasMariah Carey73108',
#  'A Christmas Gift For You From Phil SpectorVarious Artists111023',
#  'Certified Lover BoyDrake18117',
#  'Fighting DemonsJuice WRLD923',
#  'The HighlightsThe Weeknd21246',
#  'The Andy Williams Christmas AlbumAndy Williams171421',
#  'Planet HerDoja Cat23227',
#  '=Ed Sheeran1519',
#  'The Classic Christmas AlbumPerry Como241722',
#  'Christmas ClassicsBing Crosby191843',
# ...

# %%
# Out:
# []

# %% [markdown]
# 3.Scrape the details of Data science recruiters from naukri.com.
# Url = https://www.naukri.com/
# You have to find the following details:
# A) Name
# B) Designation
# C) Company
# D) Skills they hire for
# E) Location

# %%
driver= webdriver.Chrome(r"C:\Users\Sanjana\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get('https://www.naukri.com/')

# %%
button=driver.find_elements_by_xpath('//ul[@class="midSec menu"]/li[2]')
button[0].click()

# %%
driver.switch_to.window(driver.window_handles[1])

# %%
search_job = driver.find_element_by_xpath("//input[@class='sugInp']")
search_job.send_keys("Data science")
search_btn = driver.find_element_by_xpath("//button[@class='fl qsbSrch blueBtn']")
search_btn.click()

# %%
Name=[]
Designation=[]
Company=[]
Skills_required=[]
Location=[]

# %%
import pandas as pd
table=pd.DataFrame({})

table['Name']=Name[:8000]
table['Designation']=Designation[:8000]
table['Company']=Company[:8000]
table['Skills they hire for']=Skills_required[:8000]
table['Location']=Location[:8000]

table

# %%
dt = driver.find_elements_by_xpath('//span[@class="fl ellipsis"]')
for d in dt:
    if d.text is None :
        Name.append('-')
    else:
        Name.append(d.text)

# %%
Name
# Out:
# ['Aakash Harit',
#  'shravan Kumar Gaddam',
#  'MARSIAN Technologies LLP',
#  'Anik Agrawal',
#  'subhas patel',
#  'Abhishek - Only Analytics Hiring - India and',
#  'Institute for Financial Management and Resear',
#  'Balu Ramesh',
#  'Asif Lucknowi',
#  'InstaFinancials',
#  'Priyanka Akiri',
#  'Kalpana Dumpala',
#  'Mubarak',
#  'Kushal Rastogi',
#  'Mahesh Babu Channa',
#  'Sakshi Chhikara',
#  'Kapil Devang',
#  'Ruchi Dhote',
#  'Sandhya Khandagale',
#  'Manisha Yadav',
#  'Riya Rajesh',
#  'Rashmi Bhattacharjee',
#  'Faizan Kareem',
#  'Rithika dadwal',
#  'Shaun Rao',
#  'Azahar Shaikh',
#  'Manas',
#  'kumar',
#  'Sunil Vedula',
#  'Rajat Kumar',
#  'Avodha',
#  'Jayanth N',
#  'Priya Khare',
#  'Dhruv Dev Dubey',
#  'Amit Sharma',
#  'Kanan',
#  'Shashikant Chaudhary',
#  'Brad',
#  'Rutuja Pawar',
#  'Madhusudhan Sridhar',
#  'Ankit Sinha',
#  'Gaurav Chouhan',
#  'Rashi Kacker',
#  'Ashwini',
#  'Balaji Kolli',
#  'Rajani Nagaraj',
#  'ROHIT Kumar',
# ...

# %%
dt = driver.find_elements_by_xpath('//span[@class="ellipsis clr"]')
for d in dt:
    if d.text is None :
        Designation.append('-')
    else:
        Designation.append(d.text)

# %%
Designation
# Out:
# ['HR Manager',
#  'Company Recruiter',
#  'Company HR',
#  'Company Recruiter',
#  'Founder CEO',
#  'Recruitment Lead Consultant',
#  'Programme Manager',
#  'HR Administrator',
#  'Director',
#  'Human Resource',
#  'HR Manager',
#  'Executive Hiring',
#  'Company HR',
#  'Company HR',
#  'HR Team Lead',
#  'Assistant Manager HR',
#  'HR Manager',
#  'Senior Executive Talent Acquisition',
#  'HR Recruiter',
#  'HR Executive',
#  'Manager Talent Acquisition',
#  'HR Head',
#  'HR MANAGER',
#  'HR Recruiter',
#  'Manager Human Resources',
#  'Company Recruiter',
#  'Lead Talent acquisition',
#  'Proprietor',
#  'CEO',
#  'Founder CEO',
#  'Business Development Associate',
#  'Project Manager',
#  'Senior Manager',
#  'Company Recruitment Head',
#  'Consultant',
#  'senior technology instructor',
#  'HR Recruiter/HR Excutive',
#  'Manager, Technical Recruiting',
#  'Technical Recruiter',
#  'Erp Implementer',
#  'Head Analytics',
#  'Chief Technical Officer',
#  'Sr Product Manager',
# ...

# %%
dt = driver.find_elements_by_xpath('//p[@class="highlightable"]/a[2]')
for d in dt:
    if d.text is None :
        Company.append('-')
    else:
        Company.append(d.text)

# %%
Company
# Out:
# ['Data Science Network',
#  'Shore Infotech India Pvt. Ltd',
#  'MARSIAN Technologies LLP',
#  'Enerlytics Software Solutions Pvt Ltd',
#  'LibraryXProject',
#  'Apidel Technologies Division of Transpower',
#  'IFMR',
#  'Techvantage Systems Pvt Ltd',
#  'Weupskill- Live Wire India',
#  'CBL Data Science Private Limited',
#  'Infinitive Software Solutions',
#  'Innominds Software',
#  'MoneyTap',
#  'QuantMagnum Technologies Pvt. Ltd.',
#  'SocialPrachar.com',
#  'BIZ INFOTECNO PRIVATE LIMITED',
#  'BISP Solutions',
#  'Bristlecone India Ltd',
#  'Compumatrice Multimedia Pvt Ltd',
#  'Easi Tax',
#  'Novelworx Digital Solutions',
#  'AXESTRACK SOFTWARE SOLUTIONS PRIVATE...',
#  'FirstTech Consaltants Pvt.Ltd',
#  'Affine Analytics',
#  'Exela Technologies',
#  'NEAL ANALYTICS SERVICES PVT LTD',
#  'Autumn Leaf Consulting Services Private...',
#  'trainin',
#  'Nanoprecise Sci Corp',
#  'R.S Consultancy &amp; Services',
#  'Nikitha Palaparthi',
# ...

# %%
dt = driver.find_elements_by_xpath('//div[@class="hireSec highlightable"]')
for d in dt:
    if d.text is None :
        Skills_required.append('-')
    else:
        Skills_required.append(d.text)

# %%
Skills_required
# Out:
# ['Classic ASP Developer, Internet Marketing Professional, Data Science SME, Content Writers, SEO Professional, Revenue Professional',
#  '.Net, Java, Data Science, Linux Administration, Sql Server Development, Winforms, Wcf Services, Wpf, Telecom Engineering, Technical Management, Software',
#  'Data Science, Artificial Intelligence, Machine Learning, Business Analytics',
#  'Mean Stack, javascript, angularjs, mongodb, Web Services, rest, express, Node.js, Big Data, iot, Data Science, Cloud Computing, saas, Aws',
#  'Hadoop, Spark, Digital Strategy, Data Architecture, Command Center, Cdp, Dmp, Kafka, Data Science, Data Analysis, Big Data Analytics, Real Time Analysis, SQL',
#  'Analytics, Business Intelligence, Business Analytics, Predictive Modeling, Predictive Analytics, Data Science, Data Analysis, Data Analytics, Big Data, Big',
#  'Data Science',
# ...

# %%
dt = driver.find_elements_by_xpath('//small[@class="ellipsis"]')
for d in dt:
    if d.text is None :
        Location.append('-')
    else:
        Location.append(d.text)

# %%
Location
# Out:
# ['Delhi',
#  'Hyderabad / Secunderabad',
#  'Pune',
#  'Ahmedabad',
#  'UK - (london)',
#  'Vadodara / Baroda',
#  'Chennai',
#  'Trivandrum',
#  'Indore',
#  'Bengaluru / Bangalore',
#  'Hyderabad',
#  'Hyderabad / Secunderabad',
#  'Bengaluru / Bangalore',
#  'Mumbai',
#  'Hyderabad / Secunderabad',
#  'Chandigarh',
#  'Bhopal',
#  'Pune',
#  'Pune',
#  'Navi Mumbai',
#  'Cochin',
#  'Delhi',
#  'Hyderabad / Secunderabad',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Bengaluru / Bangalore',
#  'Bengaluru / Bangalore',
#  'Delhi',
#  'Hyderabad / Secunderabad',
#  'Mysoru / Mysore',
#  'Bengaluru / Bangalore',
#  'Bengaluru / Bangalore',
#  'New Delhi',
#  'Chennai',
#  'Aligarh',
#  'Salt Lake City',
#  'Pune',
#  'Bengaluru / Bangalore',
#  'Mumbai',
#  'Indore',
#  'Bengaluru / Bangalore',
#  'MYSORE',
#  'Hyderabad / Secunderabad',
#  'Bengaluru / Bangalore',
#  'Mumbai',
#  'Hyderabad / Secunderabad',
#  'Bengaluru / Bangalore',
#  'Delhi',
#  'Hyderabad / Secunderabad',
#  'Pune',
# ...

# %%
import pandas as pd
table=pd.DataFrame({})

table['Name']=Name[:100]
table['Designation']=Designation[:100]
table['Company']=Company[:100]
table['Skills they hire for']=Skills_required[:100]
table['Location']=Location[:100]

table
# Out:
#                         Name             Designation  \
# 0               Aakash Harit              HR Manager
# 1       shravan Kumar Gaddam       Company Recruiter
# 2   MARSIAN Technologies LLP              Company HR
# 3               Anik Agrawal       Company Recruiter
# 4               subhas patel             Founder CEO
# ..                       ...                     ...
# 95            Rajani Nagaraj              HR Manager
# 96               ROHIT Kumar               Architect
# 97            Amir Chowdhury        Managing Partner
# 98                  SREEDHAR  Recruitment Consultant
# 99         Radha Manivasagam            HR Executive
#
#                                         Company  \
# 0                          Data Science Network
# 1                 Shore Infotech India Pvt. Ltd
# 2                      MARSIAN Technologies LLP
# 3         Enerlytics Software Solutions Pvt Ltd
# 4                               LibraryXProject
# ...

# %% [markdown]
# Q8. Scrape the details of Highest selling novels. Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/ You have to find the following details: A) Book name B) Author name C) Volumes sold D) Publisher E) Genre

# %%
driver= webdriver.Chrome(r"C:\Users\Sanjana\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get('https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare')

# %%
Book_name=[]
Author_name=[]
Volumes_sold=[]
Publisher=[]
Genre=[]

# %%
dt = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[2]')
for d in dt:
    if d.text is None :
        Book_name.append('-')
    else:
        Book_name.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[3]')
for d in dt:
    if d.text is None :
        Author_name.append('-')
    else:
        Author_name.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[4]')
for d in dt:
    if d.text is None :
        Volumes_sold.append('-')
    else:
        Volumes_sold.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[5]')
for d in dt:
    if d.text is None :
        Publisher.append('-')
    else:
        Publisher.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[6]')
for d in dt:
    if d.text is None :
        Genre.append('-')
    else:
        Genre.append(d.text)

# %%
import pandas as pd
table=pd.DataFrame({})

table['Book Name']=Book_name
table['Author Name']=Author_name
table['Volumes Sold']=Volumes_sold
table['Publisher']=Publisher
table['Genre']=Genre

table
# Out:
#                                             Book Name       Author Name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes Sold        Publisher                        Genre
# ...

# %% [markdown]
# Q9.Scrape the details most watched tv series of all time from imdb.com. Url = https://www.imdb.com/list/ls095964455/ You have to find the following details: A) Name B) Year span C) Genre D) Run time E) Ratings F) Votes

# %%
driver= webdriver.Chrome(r"C:\Users\Sanjana\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get('https://www.imdb.com/list/ls095964455/')

# %%
Name=[]
Year_span=[]
Genre=[]
Run_time=[] 
Ratings=[]
Votes=[]

# %%
dt = driver.find_elements_by_xpath('//h3[@class="lister-item-header"]/a')
for d in dt:
    if d.text is None :
        Name.append('-')
    else:
        Name.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//span[@class="lister-item-year text-muted unbold"]')
for d in dt:
    if d.text is None :
        Year_span.append('-')
    else:
        Year_span.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//span[@class="genre"]')
for d in dt:
    if d.text is None :
        Genre.append('-')
    else:
        Genre.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//span[@class="runtime"]')
for d in dt:
    if d.text is None :
        Run_time.append('-')
    else:
        Run_time.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//div[@class="ipl-rating-star small"]/span[2]')
for d in dt:
    if d.text is None :
        Ratings.append('-')
    else:
        Ratings.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//span[@name="nv"]')
for d in dt:
    if d.text is None :
        Votes.append('-')
    else:
        Votes.append(d.text)

# %%
import pandas as pd
table=pd.DataFrame({})

table['Name']=Name
table['Year Span']=Year_span
table['Genre']=Genre
table['Run Time']=Run_time
table['Votes']=Votes

table
# Out:
#                               Name    Year Span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run Time      Votes
# 0    57 min  1,927,415
# 1    51 min    949,627
# ...

# %% [markdown]
# Q10. Details of Datasets from UCI machine learning repositories. Url = https://archive.ics.uci.edu/ You have to find the following details: A) Dataset name B) Data type C) Task D) Attribute type E) No of instances F) No of attribute G) Year Note: - from the home page you have to go to the ShowAllDataset page through code.

# %%
driver= webdriver.Chrome(r"C:\Users\Sanjana\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get('https://archive.ics.uci.edu/')

# %%
d = driver.find_element_by_xpath('//span[@class="normal"]/b')
d.click()

# %%
Dataset_name=[]
Data_type=[]
Task=[]
Attribute_type=[]
instances=[]
attribute=[]
Year=[]

# %%
dt = driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr/td[1]/table/tbody/tr/td[2]/p/b')
for d in dt:
    if d.text is None :
        Dataset_name.append('-')
    else:
        Dataset_name.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr/td[2]')
for d in dt:
    if d.text is None :
        Data_type.append('-')
    else:
        Data_type.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr/td[3]')
for d in dt:
    if d.text is None :
        Task.append('-')
    else:
        Task.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr/td[4]')
for d in dt:
    if d.text is None :
        Attribute_type.append('-')
    else:
        Attribute_type.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr/td[5]')
for d in dt:
    if d.text is None :
        instances.append('-')
    else:
        instances.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr/td[6]')
for d in dt:
    if d.text is None :
        attribute.append('-')
    else:
        attribute.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr/td[7]')
for d in dt:
    if d.text is None :
        Year.append('-')
    else:
        Year.append(d.text)

# %%
print(len(Dataset_name))
print(len(Data_type))
print(len(Task))
print(len(Attribute_type))
print(len(instances))
print(len(attribute))
print(len(Year))
# Out:
# 622
# 623
# 623
# 623
# 623
# 623
# 623

# %%
import pandas as pd
table=pd.DataFrame({})

table['Dataset Name']=Dataset_name[1:620]
table['Data Type']=Data_type[1:620]
table['Task']=Task[1:620]
table['Attribute Type']=Attribute_type[1:620]
table['Instances']=instances[1:620]
table['Attribute']=attribute[1:620]
table['Year']=Year[1:620]

# %%
table
# Out:
#                                           Dataset Name      Data Type  \
# 0                                                Adult  Multivariate
# 1                                            Annealing  Multivariate
# 2                         Anonymous Microsoft Web Data  Multivariate
# 3                                           Arrhythmia
# 4                                Artificial Characters  Multivariate
# ..                                                 ...            ...
# 614                                           REJAFADA  Multivariate
# 615          Steel Industry Energy Consumption Dataset  Multivariate
# 616  Influenza outbreak event prediction via Twitte...  Multivariate
# 617                      Turkish Music Emotion Dataset  Multivariate
# 618                      Maternal Health Risk Data Set  Multivariate
#
#                      Task               Attribute Type Instances Attribute  \
# ...
